# %%
#導入所需套件
from sklearn.externals import joblib 

#匯入模型
reg1 = joblib.load('right_size.pkl')
reg2 = joblib.load('left_size.pkl')
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
#導入所需套件
import pandas as pd
import numpy as np
import os

path='Test_DataSet\\'
file_path=os.listdir(path)
right_list=list()
left_list=list()

#使用for迴圈設定完整的.xlsx路徑，讀進raw data後放入right_list及left_list
for i in file_path:
    if i!='test_main_table.xlsx':
        dat_path=path+i
        excel_path=os.listdir(dat_path)
        for j in excel_path:
            if j=='pressure.xlsx':
                A=pd.read_excel(dat_path+"\\"+j)
                A=A.drop(['Unnamed: 0','TimeStamp'], axis=1)                
                for k in A:
                    if k=='pressure_right':
                        right_list.append([A[k]])
                    elif k=='pressure_left':
                        left_list.append([A[k]])
print("right_list_shape:",str(np.array(right_list).shape))
print("left_list_shape:",str(np.array(left_list).shape))
# Out:
# right_list_shape: (40, 1)
# left_list_shape: (40, 1)

# %%
#導入所需套件
from keras.preprocessing import sequence

#使用pad_sequences進行data補值，並轉換list維度
cnt=0
for i in right_list:
    right_list[cnt]=sequence.pad_sequences(i,dtype='float64',maxlen=7443)          
    cnt+=1
print("right_list_shape:",str(np.array(right_list).shape))                                  
right_list = np.reshape(right_list,(-1,7443))                           #三維轉二維
print("right_list_shape:",str(np.array(right_list).shape))              

cnt=0
for i in left_list:
    left_list[cnt]=sequence.pad_sequences(i,dtype='float64',maxlen=7443)          
    cnt+=1
print("left_list_shape:",str(np.array(left_list).shape))                                  
left_list = np.reshape(left_list,(-1,7443))                           #三維轉二維
print("left_list_shape:",str(np.array(left_list).shape))
# Out:
# Using TensorFlow backend.
# right_list_shape: (40, 1, 7443)
# right_list_shape: (40, 7443)
# left_list_shape: (40, 1, 7443)
# left_list_shape: (40, 7443)

# %%
#導入所需套件
from sklearn import preprocessing

#對data進行正規化計算
right_list=right_list/right_list.max()
print("right_list[39]:",right_list[39])

left_list=left_list/left_list.max()
print("left_list[39]:",left_list[39])
# Out:
# right_list[39]: [0.         0.         0.         ... 0.00942127 0.00807537 0.00807537]
# left_list[39]: [0.         0.         0.         ... 0.00846262 0.00987306 0.00987306]

# %%
#對測試集進行預測
right_predict=reg1.predict(right_list)
print("Rihgt predict size:",right_predict)

left_predict=reg2.predict(left_list)
print("Left predict size:",left_predict)
# Out:
# Rihgt predict size: [36.15554674 36.17322788 36.19368353 36.17903081 36.18234589 36.18236476
#  36.17210125 36.14940449 36.1227885  36.16111353 36.14342487 36.11606351
#  36.18333377 36.1437781  36.12849539 36.14718434 36.15984015 36.1519972
#  36.15691517 36.14763656 36.18252175 36.14605064 36.10511834 36.15547783
#  36.13659563 36.12932577 36.1733034  36.15103136 36.14657511 36.16821155
#  36.16584083 36.15348527 36.14089425 36.18567171 36.12843545 36.16955079
#  36.07081206 36.15250931 36.14326363 36.15626148]
# Left predict size: [36.12966529 36.1500503  36.17883493 36.17796711 36.17213527 36.16002786
#  36.09414746 36.11074336 36.07784024 36.10608061 36.05466764 36.06080056
#  36.08784396 36.10261422 36.06857949 36.1205622  36.09863269 36.09175516
#  36.13662546 36.11067539 36.01205456 36.10206113 36.06371075 36.08565616
#  36.08581083 36.07769148 36.1308452  36.0749231  36.10692421 36.10382237
#  36.12525916 36.1224705  36.10021796 36.16361876 36.10405195 36.11549494
#  35.9486721  36.11804099 36.07369343 36.12671593]

# %%
#把預測結果印出並儲存在test_quality_size.xlsx
sub=pd.DataFrame(columns=['key','left','right'])
key=list()
for i in file_path[0:40]:
    key.append(i[5:])
sub['key']=key
sub['left']=left_predict
sub['right']=right_predict
sub.to_excel('test_quality_size.xlsx')
sub
# Out:
#                key       left      right
# 0   20190709144841  36.129665  36.155547
# 1   20190709144911  36.150050  36.173228
# 2   20190709145610  36.178835  36.193684
# 3   20190709145848  36.177967  36.179031
# 4   20190709150235  36.172135  36.182346
# 5   20190709150259  36.160028  36.182365
# 6   20190709152333  36.094147  36.172101
# 7   20190709152358  36.110743  36.149404
# 8   20190709152858  36.077840  36.122788
# 9   20190709153213  36.106081  36.161114
# 10  20190709153419  36.054668  36.143425
# 11  20190709153634  36.060801  36.116064
# 12  20190709153839  36.087844  36.183334
# 13  20190709154131  36.102614  36.143778
# 14  20190709154214  36.068579  36.128495
# 15  20190709155229  36.120562  36.147184
# 16  20190709155457  36.098633  36.159840
# 17  20190709155627  36.091755  36.151997
# 18  20190709155650  36.136625  36.156915
# 19  20190709155710  36.110675  36.147637
# 20  20190709155733  36.012055  36.182522
# 21  20190709155944  36.102061  36.146051
# 22  20190709160009  36.063711  36.105118
# 23  20190709160253  36.085656  36.155478
# 24  20190709160317  36.085811  36.136596
# 25  20190709160816  36.077691  36.129326
# 26  20190709161421  36.130845  36.173303
# 27  20190709161725  36.074923  36.151031
# 28  20190709161750  36.106924  36.146575
# 29  20190709161900  36.103822  36.168212
# 30  20190709162011  36.125259  36.165841
# 31  20190709162334  36.122470  36.153485
# 32  20190709162657  36.100218  36.140894
# 33  20190709162900  36.163619  36.185672
# 34  20190709162921  36.104052  36.128435
# 35  20190709163006  36.115495  36.169551
# 36  20190709163123  35.948672  36.070812
# 37  20190709163317  36.118041  36.152509
# 38  20190709163405  36.073693  36.143264
# 39  20190709163427  36.126716  36.156261
